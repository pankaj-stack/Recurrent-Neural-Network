# %% [markdown]
# - low dimention ka vector ka jo variance hota hai vo km hota agar high dimention ka vector hai to uska variance jyada hoga.
# - yhan variance ka whi meaning hai ki data failav.
# - high variance ka matlab problem.
# - softmax function ka nature esa hota hai ki agar isko aap bare no. doge to proability jyada dega aur chota number doge to probability chota dega.
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# - dimenton of the array/vector is directly proportional to the variance.
# - self attention variance ko km krne ke liye root over dimention (root d) se divide krte hain jisse phir hamari  training achchi hoti hai.
