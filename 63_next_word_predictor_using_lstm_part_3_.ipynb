# %%
faqs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at nitish.campusx@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

tokenizer.fit_on_texts([faqs])

len(tokenizer.word_index)

input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

input_sequences

max_len = max([len(x) for x in input_sequences])

from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

padded_input_sequences

X = padded_input_sequences[:,:-1]

y = padded_input_sequences[:,-1]

X.shape

y.shape



from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=283)

y.shape

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(283, 100, input_length=56))# yhan pe 283 length of the type of words,100 is the no. of embedding node and input_length=56 is a each word in a sentence of the document.
model.add(LSTM(150,return_sequences=True))
model.add(LSTM(150))
model.add(Dense(283, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

model.summary()

model.fit(X,y,epochs=100,validation_split=0.2)
# embedding ka matlab yhan pe ye hai ki sentence ke har ek word ko 100-dimentional vector  me convert kr dega
# Out:
# 2024-05-21 11:32:41.928602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:41.930054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:41.931186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 56, 100)           28300
#
#  lstm_17 (LSTM)              (None, 56, 150)           150600
#
#  lstm_18 (LSTM)              (None, 150)               180600
#
#  dense_5 (Dense)             (None, 283)               42733
#
# =================================================================
# Total params: 402,233
# Trainable params: 402,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2024-05-21 11:32:42.136839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:42.138396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:42.139544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-21 11:32:42.439320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:42.440743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:42.441976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-21 11:32:42.637721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:42.639043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:42.640280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-21 11:32:43.745331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:43.746988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:43.748216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-21 11:32:43.936279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:43.937514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:43.938720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 21/22 [===========================>..] - ETA: 0s - loss: 5.4063 - accuracy: 0.0729
# 2024-05-21 11:32:47.008857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:47.010292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:47.011526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-21 11:32:47.192524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-21 11:32:47.193618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-21 11:32:47.194742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 22/22 [==============================] - 5s 101ms/step - loss: 5.4065 - accuracy: 0.0754 - val_loss: 5.4416 - val_accuracy: 0.0462
# Epoch 2/100
# 22/22 [==============================] - 2s 67ms/step - loss: 5.0078 - accuracy: 0.0855 - val_loss: 5.6741 - val_accuracy: 0.0462
# Epoch 3/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.9387 - accuracy: 0.0855 - val_loss: 5.8430 - val_accuracy: 0.0462
# Epoch 4/100
# 22/22 [==============================] - 2s 69ms/step - loss: 4.9248 - accuracy: 0.0855 - val_loss: 5.9595 - val_accuracy: 0.0462
# Epoch 5/100
# 22/22 [==============================] - 1s 68ms/step - loss: 4.9221 - accuracy: 0.0855 - val_loss: 6.0076 - val_accuracy: 0.0462
# Epoch 6/100
# 22/22 [==============================] - 1s 68ms/step - loss: 4.9084 - accuracy: 0.0855 - val_loss: 6.0494 - val_accuracy: 0.0462
# Epoch 7/100
# 22/22 [==============================] - 2s 71ms/step - loss: 4.9044 - accuracy: 0.0855 - val_loss: 6.0779 - val_accuracy: 0.0462
# Epoch 8/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.8972 - accuracy: 0.0855 - val_loss: 6.1728 - val_accuracy: 0.0462
# Epoch 9/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.8795 - accuracy: 0.0855 - val_loss: 6.1291 - val_accuracy: 0.0462
# Epoch 10/100
# 22/22 [==============================] - 2s 69ms/step - loss: 4.8507 - accuracy: 0.0855 - val_loss: 6.1839 - val_accuracy: 0.0462
# Epoch 11/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.7808 - accuracy: 0.0855 - val_loss: 6.1824 - val_accuracy: 0.0462
# Epoch 12/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.6764 - accuracy: 0.0855 - val_loss: 5.9971 - val_accuracy: 0.0462
# Epoch 13/100
# 22/22 [==============================] - 2s 69ms/step - loss: 4.5531 - accuracy: 0.0899 - val_loss: 6.2518 - val_accuracy: 0.0578
# Epoch 14/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.3969 - accuracy: 0.1188 - val_loss: 6.0966 - val_accuracy: 0.1098
# Epoch 15/100
# 22/22 [==============================] - 1s 68ms/step - loss: 4.2155 - accuracy: 0.1478 - val_loss: 6.1584 - val_accuracy: 0.0925
# Epoch 16/100
# 22/22 [==============================] - 1s 67ms/step - loss: 4.0525 - accuracy: 0.1580 - val_loss: 6.1556 - val_accuracy: 0.1040
# Epoch 17/100
# 22/22 [==============================] - 1s 68ms/step - loss: 3.8861 - accuracy: 0.2029 - val_loss: 6.2218 - val_accuracy: 0.1272
# Epoch 18/100
# 22/22 [==============================] - 2s 69ms/step - loss: 3.7199 - accuracy: 0.2043 - val_loss: 6.1518 - val_accuracy: 0.1156
# Epoch 19/100
# 22/22 [==============================] - 1s 66ms/step - loss: 3.5548 - accuracy: 0.2333 - val_loss: 6.1528 - val_accuracy: 0.1156
# Epoch 20/100
# 22/22 [==============================] - 1s 67ms/step - loss: 3.4006 - accuracy: 0.2507 - val_loss: 6.1805 - val_accuracy: 0.1214
# Epoch 21/100
# 22/22 [==============================] - 2s 69ms/step - loss: 3.2428 - accuracy: 0.2696 - val_loss: 6.2198 - val_accuracy: 0.1272
# Epoch 22/100
# 22/22 [==============================] - 1s 67ms/step - loss: 3.1182 - accuracy: 0.2971 - val_loss: 6.2199 - val_accuracy: 0.1214
# Epoch 23/100
# 22/22 [==============================] - 2s 69ms/step - loss: 2.9864 - accuracy: 0.3290 - val_loss: 6.2521 - val_accuracy: 0.1329
# Epoch 24/100
# 22/22 [==============================] - 1s 68ms/step - loss: 2.8322 - accuracy: 0.3551 - val_loss: 6.2774 - val_accuracy: 0.1329
# Epoch 25/100
# 22/22 [==============================] - 1s 67ms/step - loss: 2.7138 - accuracy: 0.3768 - val_loss: 6.3336 - val_accuracy: 0.1503
# Epoch 26/100
# 22/22 [==============================] - 1s 68ms/step - loss: 2.6069 - accuracy: 0.3971 - val_loss: 6.3050 - val_accuracy: 0.1618
# Epoch 27/100
# 22/22 [==============================] - 1s 68ms/step - loss: 2.4814 - accuracy: 0.4188 - val_loss: 6.3760 - val_accuracy: 0.1618
# Epoch 28/100
# 22/22 [==============================] - 2s 69ms/step - loss: 2.3826 - accuracy: 0.4435 - val_loss: 6.3132 - val_accuracy: 0.1676
# Epoch 29/100
# 22/22 [==============================] - 2s 67ms/step - loss: 2.2779 - accuracy: 0.4667 - val_loss: 6.3964 - val_accuracy: 0.1676
# Epoch 30/100
# 22/22 [==============================] - 1s 66ms/step - loss: 2.1690 - accuracy: 0.4812 - val_loss: 6.4164 - val_accuracy: 0.1908
# Epoch 31/100
# 22/22 [==============================] - 2s 69ms/step - loss: 2.0742 - accuracy: 0.5130 - val_loss: 6.4652 - val_accuracy: 0.1908
# Epoch 32/100
# 22/22 [==============================] - 2s 69ms/step - loss: 1.9836 - accuracy: 0.5478 - val_loss: 6.4811 - val_accuracy: 0.1792
# Epoch 33/100
# 22/22 [==============================] - 2s 72ms/step - loss: 1.9074 - accuracy: 0.5565 - val_loss: 6.5143 - val_accuracy: 0.1908
# Epoch 34/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.8212 - accuracy: 0.5826 - val_loss: 6.5340 - val_accuracy: 0.2081
# Epoch 35/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.7326 - accuracy: 0.6072 - val_loss: 6.5267 - val_accuracy: 0.2081
# Epoch 36/100
# 22/22 [==============================] - 1s 68ms/step - loss: 1.6552 - accuracy: 0.6188 - val_loss: 6.5174 - val_accuracy: 0.2139
# Epoch 37/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.5810 - accuracy: 0.6710 - val_loss: 6.6096 - val_accuracy: 0.2139
# Epoch 38/100
# 22/22 [==============================] - 1s 68ms/step - loss: 1.5030 - accuracy: 0.7014 - val_loss: 6.5763 - val_accuracy: 0.2197
# Epoch 39/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.4391 - accuracy: 0.7188 - val_loss: 6.6368 - val_accuracy: 0.2139
# Epoch 40/100
# 22/22 [==============================] - 1s 65ms/step - loss: 1.3743 - accuracy: 0.7290 - val_loss: 6.6896 - val_accuracy: 0.2254
# Epoch 41/100
# 22/22 [==============================] - 2s 69ms/step - loss: 1.3087 - accuracy: 0.7420 - val_loss: 6.6759 - val_accuracy: 0.2486
# Epoch 42/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.2489 - accuracy: 0.7667 - val_loss: 6.6760 - val_accuracy: 0.2543
# Epoch 43/100
# 22/22 [==============================] - 1s 68ms/step - loss: 1.1881 - accuracy: 0.7797 - val_loss: 6.7184 - val_accuracy: 0.2428
# Epoch 44/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.1323 - accuracy: 0.8014 - val_loss: 6.7450 - val_accuracy: 0.2428
# Epoch 45/100
# 22/22 [==============================] - 1s 66ms/step - loss: 1.0772 - accuracy: 0.8174 - val_loss: 6.7875 - val_accuracy: 0.2486
# Epoch 46/100
# 22/22 [==============================] - 2s 71ms/step - loss: 1.0270 - accuracy: 0.8275 - val_loss: 6.7822 - val_accuracy: 0.2428
# Epoch 47/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.9781 - accuracy: 0.8493 - val_loss: 6.8392 - val_accuracy: 0.2543
# Epoch 48/100
# 22/22 [==============================] - 2s 70ms/step - loss: 0.9341 - accuracy: 0.8536 - val_loss: 6.8299 - val_accuracy: 0.2486
# Epoch 49/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.8946 - accuracy: 0.8623 - val_loss: 6.8455 - val_accuracy: 0.2428
# Epoch 50/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.8547 - accuracy: 0.8652 - val_loss: 6.8219 - val_accuracy: 0.2428
# Epoch 51/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.8112 - accuracy: 0.8725 - val_loss: 6.8484 - val_accuracy: 0.2543
# Epoch 52/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.7794 - accuracy: 0.8754 - val_loss: 6.9073 - val_accuracy: 0.2486
# Epoch 53/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.7445 - accuracy: 0.8841 - val_loss: 6.9408 - val_accuracy: 0.2601
# Epoch 54/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.7107 - accuracy: 0.8899 - val_loss: 6.9815 - val_accuracy: 0.2428
# Epoch 55/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.6822 - accuracy: 0.8913 - val_loss: 6.9650 - val_accuracy: 0.2428
# Epoch 56/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.6544 - accuracy: 0.8957 - val_loss: 6.9855 - val_accuracy: 0.2543
# Epoch 57/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.6219 - accuracy: 0.9058 - val_loss: 7.0066 - val_accuracy: 0.2486
# Epoch 58/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.5994 - accuracy: 0.9029 - val_loss: 7.0399 - val_accuracy: 0.2428
# Epoch 59/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.5788 - accuracy: 0.9130 - val_loss: 7.0509 - val_accuracy: 0.2543
# Epoch 60/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.5558 - accuracy: 0.9174 - val_loss: 7.0711 - val_accuracy: 0.2486
# Epoch 61/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.5346 - accuracy: 0.9145 - val_loss: 7.0814 - val_accuracy: 0.2486
# Epoch 62/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.5129 - accuracy: 0.9232 - val_loss: 7.1194 - val_accuracy: 0.2543
# Epoch 63/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.4950 - accuracy: 0.9290 - val_loss: 7.1179 - val_accuracy: 0.2428
# Epoch 64/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.4788 - accuracy: 0.9246 - val_loss: 7.1642 - val_accuracy: 0.2486
# Epoch 65/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.4612 - accuracy: 0.9246 - val_loss: 7.1397 - val_accuracy: 0.2486
# Epoch 66/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.4441 - accuracy: 0.9304 - val_loss: 7.1701 - val_accuracy: 0.2543
# Epoch 67/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.4340 - accuracy: 0.9290 - val_loss: 7.1849 - val_accuracy: 0.2428
# Epoch 68/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.4134 - accuracy: 0.9304 - val_loss: 7.2292 - val_accuracy: 0.2486
# Epoch 69/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.4001 - accuracy: 0.9377 - val_loss: 7.2250 - val_accuracy: 0.2543
# Epoch 70/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.3891 - accuracy: 0.9348 - val_loss: 7.2465 - val_accuracy: 0.2486
# Epoch 71/100
# 22/22 [==============================] - 2s 72ms/step - loss: 0.3751 - accuracy: 0.9406 - val_loss: 7.2501 - val_accuracy: 0.2601
# Epoch 72/100
# 22/22 [==============================] - 2s 68ms/step - loss: 0.3622 - accuracy: 0.9377 - val_loss: 7.2806 - val_accuracy: 0.2486
# Epoch 73/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.3524 - accuracy: 0.9391 - val_loss: 7.2850 - val_accuracy: 0.2486
# Epoch 74/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.3432 - accuracy: 0.9377 - val_loss: 7.3204 - val_accuracy: 0.2428
# Epoch 75/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.3316 - accuracy: 0.9377 - val_loss: 7.3147 - val_accuracy: 0.2486
# Epoch 76/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.3203 - accuracy: 0.9377 - val_loss: 7.3758 - val_accuracy: 0.2543
# Epoch 77/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.3117 - accuracy: 0.9391 - val_loss: 7.3656 - val_accuracy: 0.2543
# Epoch 78/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.3019 - accuracy: 0.9420 - val_loss: 7.3594 - val_accuracy: 0.2486
# Epoch 79/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.2951 - accuracy: 0.9377 - val_loss: 7.4071 - val_accuracy: 0.2486
# Epoch 80/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.2875 - accuracy: 0.9391 - val_loss: 7.4037 - val_accuracy: 0.2543
# Epoch 81/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.2817 - accuracy: 0.9377 - val_loss: 7.3990 - val_accuracy: 0.2486
# Epoch 82/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.2735 - accuracy: 0.9449 - val_loss: 7.4017 - val_accuracy: 0.2543
# Epoch 83/100
# 22/22 [==============================] - 2s 69ms/step - loss: 0.2646 - accuracy: 0.9420 - val_loss: 7.4129 - val_accuracy: 0.2543
# Epoch 84/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.2589 - accuracy: 0.9464 - val_loss: 7.4155 - val_accuracy: 0.2486
# Epoch 85/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.2528 - accuracy: 0.9406 - val_loss: 7.4745 - val_accuracy: 0.2486
# Epoch 86/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.2495 - accuracy: 0.9406 - val_loss: 7.4616 - val_accuracy: 0.2486
# Epoch 87/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.2432 - accuracy: 0.9348 - val_loss: 7.4835 - val_accuracy: 0.2601
# Epoch 88/100
# 22/22 [==============================] - 2s 69ms/step - loss: 0.2362 - accuracy: 0.9435 - val_loss: 7.4829 - val_accuracy: 0.2486
# Epoch 89/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.2305 - accuracy: 0.9435 - val_loss: 7.5396 - val_accuracy: 0.2486
# Epoch 90/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.2262 - accuracy: 0.9464 - val_loss: 7.5314 - val_accuracy: 0.2486
# Epoch 91/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.2237 - accuracy: 0.9435 - val_loss: 7.5197 - val_accuracy: 0.2428
# Epoch 92/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.2168 - accuracy: 0.9565 - val_loss: 7.5555 - val_accuracy: 0.2543
# Epoch 93/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.2128 - accuracy: 0.9449 - val_loss: 7.5723 - val_accuracy: 0.2486
# Epoch 94/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.2097 - accuracy: 0.9406 - val_loss: 7.5897 - val_accuracy: 0.2543
# Epoch 95/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.2061 - accuracy: 0.9435 - val_loss: 7.6036 - val_accuracy: 0.2486
# Epoch 96/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.2019 - accuracy: 0.9435 - val_loss: 7.6062 - val_accuracy: 0.2543
# Epoch 97/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.1965 - accuracy: 0.9493 - val_loss: 7.6177 - val_accuracy: 0.2486
# Epoch 98/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.1934 - accuracy: 0.9464 - val_loss: 7.6504 - val_accuracy: 0.2543
# Epoch 99/100
# 22/22 [==============================] - 1s 66ms/step - loss: 0.1893 - accuracy: 0.9478 - val_loss: 7.6110 - val_accuracy: 0.2543
# Epoch 100/100
# 22/22 [==============================] - 1s 68ms/step - loss: 0.1859 - accuracy: 0.9464 - val_loss: 7.6223 - val_accuracy: 0.2543

# %%
import time
import numpy as np 

# text = "mail"
text = 'course fee'

for i in range(20):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
print(text)
      # time.sleep(2)

# tokenizer.word_index
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# course fee on job hunting strategies so where you have to make monthly payments of rs 799 month feb month feb month

# %%
faqs
# Out:
# 'About the Program\nWhat is the course fee for  Data Science Mentorship Program (DSMP 2023)\nThe course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.\nWhat is the total duration of the course?\nThe total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)\nWhat is the syllabus of the mentorship program?\nWe will be covering the following modules:\nPython Fundamentals\nPython libraries for Data Science\nData Analysis\nSQL for Data Science\nMaths for Machine Learning\nML Algorithms\nPractical ML\nMLOPs\nCase studies\nYou can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390\nWill Deep Learning and NLP be a part of this program?\nNo, NLP and Deep Learning both are not a part of this program’s curriculum.\nWhat if I miss a live session? Will I get a recording of the session?\nYes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.\nWhere can I find the class schedule?\nCheckout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.\nWhat is the time duration of all the live sessions?\nRoughly, all the sessions last 2 hours.\nWhat is the language spoken by the instructor during the sessions?\nHinglish\nHow will I be informed about the upcoming class?\nYou will get a mail from our side before every paid session once you become a paid user.\nCan I do this course if I am from a non-tech background?\nYes, absolutely.\nI am late, can I join the program in the middle?\nAbsolutely, you can join the program anytime.\nIf I join/pay in the middle, will I be able to see all the past lectures?\nYes, once you make the payment you will be able to see all the past content in your dashboard.\nWhere do I have to submit the task?\nYou don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.\nWill we do case studies in the program?\nYes.\nWhere can we contact you?\nYou can mail us at nitish.campusx@gmail.com\nPayment/Registration related questions\nWhere do we have to make our payments? Your YouTube channel or website?\nYou have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/\nCan we pay the entire amount of Rs 5600 all at once?\nUnfortunately no, the program follows a monthly subscription model.\nWhat is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb\n15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.\nWhat if I don’t like the course after making the payment. What is the refund policy?\nYou get a 7 days refund period from the day you have made the payment.\nI am living outside India and I am not able to make the payment on the website, what should I do?\nYou have to contact us by sending a mail at nitish.campusx@gmail.com\nPost registration queries\nTill when can I view the paid videos on the website?\nThis one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.\nBut once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.\nWhy lifetime validity is not provided?\nBecause of the low course fee.\nWhere can I reach out in case of a doubt after the session?\nYou will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session\nIf I join ...
