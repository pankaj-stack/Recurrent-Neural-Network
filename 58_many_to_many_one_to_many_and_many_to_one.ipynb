# %% [markdown]
# #Types of Rnn

# %% [markdown]
# - 1.Many to Many
# - 2.One to Many
# - 3.Many to One
# - 4.One to One (which is not a type of RNN) <------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)
# ![M](attachment:image-2.png)

# %%
percentage = 0.30
amount = 2500000
for i in range(1,50):
    if amount >= 10000000:
        break
    amount = amount + amount*percentage
    print(f'{amount} in {i} year')
# Out:
# 3250000.0 in 1 year
# 4225000.0 in 2 year
# 5492500.0 in 3 year
# 7140250.0 in 4 year
# 9282325.0 in 5 year
# 12067022.5 in 6 year
