# %% [markdown]
# - layer  normalization is the last component.
# - normalization in deep learning : hum input data aur activation ke upar normalization lagate hain.
# - batch normalization **self attention** ke saath achche se kaam nhi kr paata hai ya batch normalization sequential data pe achche se work nhi kr paata hai.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - batch normalization **self attention** me isliye fail hota hai q ki jb hum pura ek column ka mean or standard deviation nikalte hain to us column me unneccessary 0 values dher saari hoti hain jiske karan jo mean ya standard deviation aata hai vo True nhi hota hai aur isi karan se hum batch normalization sequential data ke liye hum  use nhi krte hain
# - batch normalization me jo normalzation hota hai vo across the batch(column wise) jb **layer normalization** me across the feature(row wise) hota hai.
# - **layer normalization me jo padding wale zeros(0) dher saare the vo ab mean and standard deviation nikalne me koi problem nhi krte hai means ab jo mean and standard deviation calculate ho rhe hai vo true hai q ki hum yhan pe row-wise calculate kr rhe hain ,to jo zeros wale row hain vo  pure data ko affect nhi kr paa rhe hai in case of mean and standard deviation.
