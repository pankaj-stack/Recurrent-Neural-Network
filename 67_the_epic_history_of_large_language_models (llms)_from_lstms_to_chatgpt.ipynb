# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - bioinformatics me bhi rnn ka use hota hai jaise human genes.
# - many to one rnn is the example of sentiment analysis.
# - one to many is the example of image captioning.
# - **many to many(asnynchronous)**  is the exapmple of machine translation(google translate) ,text summarization,question answering, chatbot and speech to text(jo google ne youtube me deploy kr rakha hai) etc
#     - example : I love India : मैं भारत से प्यार करता हूँ
#     - **Mostly hum isi ki baat krenge aage chalke**
#     - bahut sare difficult nlp ke task krta hai seq to seq model.
# - many to many(synchronous) is the example of Parts of speech tagging(POS) and Named Entity Tagging(NER)

# %% [markdown]
# - **history of seq to seq models**
# - **encoder-decoder**-->**attention mechanism**-->**transformer**-->**transfer learning(using transformer)**--> **llms(large language models--> chatGPT)**

# %% [markdown]
# - encoderdecoder me lsmt hi use hota hai.
# - encoder decoder me agar 30 words se jyada ka sequence pass kiya gya to fail hone lagta hai output shi nhi aata hai.
# - **transformer** me ander encoder-decoder hi use hota hai lekin lstm use nhi hai.
# - trnasformer parallel processing krta hai it means ki ye sare words jo ki ek sequence rahenge sabhi ek saath process krta hai  jbki ye feature kisi aur architecture me nhi tha abhi tk.

# %% [markdown]
# - transformer training ko bhi reduce kr diya aur gpu ki need ko bhi km kr diya.
# - transformer ko scratch se train krna tedhi kheer hai.
# - transformer ko train krne ke liye a lot amount of data ki need hoti hai.
#     - example : approximately 1.5 lac data
# - **jeremy howard** : inka youtube channel hai jo transfer learning ka concept kisi aur ke sath milke banaye hain.
# - transfer learning is also applicable in NLP task.
# - 2018 ke pehle tk NLP ke domain me transfer-learning ka concept  nhi tha.
# - **language modeling** : ek esa model jo next word predict krta hai.
# - language modeling ek **unsupervised pretraining task** hota hai.
# - abhi hamare pass 2 models achche wale hain
#     - 1. Transformer(architecture wise)
#     - 2. Transfer learning(training wise)
# - **LLM(Large Language Model) == Transformer + Transfer Learning**

# %% [markdown]
# - LLM ke do model 2018 me launch hue :--->
#     - 1. **Google BERT** ===> Encoder only model
#     - 2. **OpenAI GPT**  ===> Encoder-Decoder model
# - upar ke in 2 models(BERT AND GPT) ko aap download krke isko aap fine tune kr sakte hain kisi bhi task ke liye jaise text-summarization,question-answering,sentiment analysis,NER,POS etc.

# %% [markdown]
# - **Qualities of LLMS** :
#     - billion(1b == 100 crores) me data hona chahiye training ke liye.
#     - GPT3 45TBs data pe train hua hai.
#     - aur ye data ebooks,websites and internet etc se liye gya.
#     - GPT3 ko train krne me **cluster of GPUs** use hue the using supercomputers jo ki 1000s NVIDIA ke GPUs use kiye gye the.
#     - training me days se leke weeks tk lage the.
#     - cost bahut aata hai.
#     - energy consumption bahut hota hai,itna hota hai ki ek chota city mahine bhar jitna electricity consume krta hai.

# %% [markdown]
# - **ChatGPT**:
#     - **GPT** ek model hai.
#     - **ChatGPT** GPT model ka ek chatbot application hai.
#     - **ChatGPT** ko banane me RLHF(Reinforcement Learning from Human Feedback) ka use kiya gya hai.ye cheeje 2 steps me hui hain.
#         - 1. Supervised Fine Tuning
#         - 2. Reinforcement learning
# - Aur inappropriate content ko bhi bahut had tak hta diya gya hai jaise agar app chatgpt se bomb banana puchoge to ye nhi batayega.
# - chatgpt me contextual point pe bahut dhyan diya gya hai.
# - aur chatgpt ko dialogue training bhi karaya gya hai ki human kaise baat krte hain.
